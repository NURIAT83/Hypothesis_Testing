# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Always state the H0 and H1 before conducting the hypothesis test.
# - Happy learning!

# %%
# import numpy and pandas

import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
#Import csv file
HYPO_df=pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
#We examine the dataset using the head() function:
HYPO_df.head()
# Out:
#                      Name                 Job Titles        Department  \
# 0  ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1       AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2       AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3         AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4         AGEE,  LAWRENCE             POLICE OFFICER            POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN        72510.0
# 1                 F           Salary            NaN        93354.0
# 2                 P           Hourly           20.0            NaN
# 3                 F           Salary            NaN       132972.0
# 4                 F           Salary            NaN        90024.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2         13.0
# 3          NaN
# 4          NaN

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:

null_name = HYPO_df['Name'].isnull().sum()
null_name
# Out:
# 0

# %%
null_jobtitle=HYPO_df['Job Titles'].isnull().sum()
null_jobtitle
# Out:
# 0

# %%
null_department=HYPO_df['Department'].isnull().sum()
null_department
# Out:
# 0

# %%
null_fullORpart=HYPO_df['Full or Part-Time'].isnull().sum()
null_fullORpart
# Out:
# 0

# %%
null_SalORHour=HYPO_df['Salary or Hourly'].isnull().sum()
null_SalORHour
# Out:
# 0

# %%
null_TypicalH=HYPO_df['Typical Hours'].isnull().sum()
null_TypicalH
# Out:
# 25528

# %%
null_AnnualSalary=HYPO_df['Annual Salary'].isnull().sum()
null_AnnualSalary
# Out:
# 8174

# %%
null_Hourlyrate=HYPO_df['Hourly Rate'].isnull().sum()
null_Hourlyrate
# Out:
# 25528

# %%
HYPO_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33702 entries, 0 to 33701
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               33702 non-null  object
#  1   Job Titles         33702 non-null  object
#  2   Department         33702 non-null  object
#  3   Full or Part-Time  33702 non-null  object
#  4   Salary or Hourly   33702 non-null  object
#  5   Typical Hours      8174 non-null   float64
#  6   Annual Salary      25528 non-null  float64
#  7   Hourly Rate        8174 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 2.1+ MB

# %%
# There are three columns that present a considerable number of null values, those columns are: Hourly Rate,Typical Hours, Annual Salary

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
Total_SalariedE=HYPO_df['Annual Salary'].count()
print(f"The number of salaried employees is {Total_SalariedE}" )
Total_HourlyE=HYPO_df['Hourly Rate'].count()
print(f"The number of hourly employees is {Total_HourlyE}" )
#The number of salaried employees more than triplicates the number of hourly employees.
# Out:
# The number of salaried employees is 25528
# The number of hourly employees is 8174

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
#Below the amount of salaried employees in each department
new_hypo_Sal = HYPO_df.groupby(['Department'], as_index=False)['Annual Salary'].count()
new_hypo_Sal
# Out:
#              Department  Annual Salary
# 0          ADMIN HEARNG             38
# 1         ANIMAL CONTRL             63
# 2              AVIATION            642
# 3     BOARD OF ELECTION            111
# 4       BOARD OF ETHICS              8
# 5         BUDGET & MGMT             42
# 6             BUILDINGS            258
# 7      BUSINESS AFFAIRS            160
# 8            CITY CLERK             88
# 9          CITY COUNCIL            288
# 10                 COPA            123
# 11     CULTURAL AFFAIRS             64
# 12                 DAIS            288
# 13         DISABILITIES             27
# 14     FAMILY & SUPPORT            299
# 15              FINANCE            499
# 16                 FIRE           4627
# 17               HEALTH            465
# 18              HOUSING             66
# 19   HOUSING & ECON DEV            151
# 20      HUMAN RELATIONS             17
# 21      HUMAN RESOURCES             75
# 22        INSPECTOR GEN             95
# ...

# %%
#Below the amount of hourly employees in each department
new_hypo_hour = HYPO_df.groupby(['Department'], as_index=False)['Hourly Rate'].count()
new_hypo_hour
# Out:
#              Department  Hourly Rate
# 0          ADMIN HEARNG            0
# 1         ANIMAL CONTRL           12
# 2              AVIATION         1214
# 3     BOARD OF ELECTION            0
# 4       BOARD OF ETHICS            0
# 5         BUDGET & MGMT            2
# 6             BUILDINGS            0
# 7      BUSINESS AFFAIRS            7
# 8            CITY CLERK            0
# 9          CITY COUNCIL           74
# 10                 COPA            0
# 11     CULTURAL AFFAIRS           10
# 12                 DAIS          745
# 13         DISABILITIES            1
# 14     FAMILY & SUPPORT          357
# 15              FINANCE           45
# 16                 FIRE            0
# 17               HEALTH            2
# 18              HOUSING            0
# 19   HOUSING & ECON DEV            3
# 20      HUMAN RELATIONS            0
# 21      HUMAN RESOURCES            0
# 22        INSPECTOR GEN            0
# 23                  LAW           48
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Import scipy and one sample test function
import scipy.stats
from scipy.stats import ttest_1samp

# %%
#We are going to clean the Nan values of the column before sampling and testing
clean_HR=HYPO_df['Hourly Rate'].dropna()
clean_HR.count()
# Out:
# 8174

# %%
#Let's check if there are any remaining nan
clean_HR.isnull().values.any()
# Out:
# False

# %%
#First we create a sample from our population(total of hourly rate employees)
#The sample will be 10% of the total population
sampleHR_df = clean_HR.sample(frac=0.1)
clean_HR
# Out:
# 2        13.00
# 5        37.45
# 15       40.78
# 16       38.52
# 21       34.98
#          ...
# 33676    25.95
# 33678    43.72
# 33681    51.43
# 33684    49.35
# 33688    37.45
# Name: Hourly Rate, Length: 8174, dtype: float64

# %%
# we can find out the sample mean, it is 
sum(clean_HR)/100
# Out:
# 2827.0964000000363

# %%
# we can find a confidence interval for the population based on our sample
import scipy.stats
#We choose a confidence level of 95%
confidence_level = 0.95
degrees_freedom = len(clean_HR) - 1  
sample_mean = np.mean(clean_HR)

# %%
sample_mean
# Out:
# 34.58644971862002

# %%
# note that we use the standard error of the sample 
# as an estimate of the standard error of the population 
sample_standard_error = scipy.stats.sem(clean_HR)

# %%
#Confidence interval
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865) .

# %%
sample_standard_error
# Out:
# 0.14694742867989574

# %%
#We calculate the sample standard error to check with the one that we have seen above with scipy
np.std(clean_HR)/np.sqrt(degrees_freedom)
# Out:
# 0.14694742867989574

# %%
#Hypothesis structure
# the hourly wage in the population is 30

# we select a value for alpha of 0.05 (p-value threshold, significance level)
# Two-sided test:
# Null hypothesis or H0: mean hourly wage = 30
# Alternative hyp or H1: mean hourly wage <> 30

# %%
#We test the hypothesis
stat, pval = ttest_1samp(clean_HR,30)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   31.211500329216044
# pvalue for the two-tailed test is  3.825475847673793e-202

# %%
# p is low, we reject the H0

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our Null hypothesis is less than or equal to, then to reject, the test statistic must be positive (rejects the <) and the p-value below 0.05 (rejects the =).

# %%
#We create a new dataframe exclusively for the police department

police = HYPO_df[HYPO_df['Department']=='POLICE']
police
# Out:
#                        Name                              Job Titles  \
# 1         AFFANEH,  MAHIR A                          POLICE OFFICER
# 4           AGEE,  LAWRENCE                          POLICE OFFICER
# 6         AGNEW,  MELISSA M                                SERGEANT
# 7         AGOSTA,  JOSEPH J  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9         AGOSTINI,  LUIS R                                ASST DIR
# ...                     ...                                     ...
# 33696  ZYLINSKA,  KATARZYNA                          POLICE OFFICER
# 33697    ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 33698    ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33699     ZYMANTAS,  MARK E                          POLICE OFFICER
# 33700   ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 1         POLICE                 F           Salary            NaN
# ...

# %%
#We reduce the dataframe to the salary column only
police_salary=police['Annual Salary'].dropna()
police_salary
# Out:
# 1         93354.0
# 4         90024.0
# 6        111444.0
# 7        103932.0
# 9         95736.0
#            ...
# 33696     80016.0
# 33697     72510.0
# 33698     76266.0
# 33699     90024.0
# 33700     93354.0
# Name: Annual Salary, Length: 13824, dtype: float64

# %%
# One-sided test:
# Null hypothesis or H0: police salary  =< 86000
# Alternative hyp or H1: police salary > 86000
stat, pval = ttest_1samp(police_salary, 86000) 
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# pvalue for the one-tailed test is  6.119566952121482e-76

# %%
# p is low,we reject the H0

# %% [markdown]
# #Using the `crosstab` function, find the department that has the most hourly workers.

# %%
data_crosstab = pd.crosstab(HYPO_df['Department'], HYPO_df['Hourly Rate'],values=HYPO_df['Name'],aggfunc=pd.Series.nunique, margins = True)
data_crosstab
# Out:
# Hourly Rate           2.65  8.25  9.74  10.0  10.5  12.0  13.0   13.4  13.45  \
# Department
# ANIMAL CONTRL          NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# AVIATION               NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# BUDGET & MGMT          NaN   NaN   NaN   NaN   NaN   NaN   2.0    NaN    NaN
# BUSINESS AFFAIRS       NaN   NaN   NaN   NaN   NaN   NaN   2.0    NaN    NaN
# CITY COUNCIL           NaN   4.0   NaN   2.0   1.0   5.0   5.0    NaN    1.0
# CULTURAL AFFAIRS       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# DAIS                   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# DISABILITIES           NaN   NaN   NaN   NaN   NaN   NaN   1.0    NaN    NaN
# FAMILY & SUPPORT     260.0   NaN   NaN   NaN   NaN   NaN  41.0    NaN    NaN
# FINANCE                NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# HEALTH                 NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# ...

# %%
#The department that has the most hourly workers is Streets & Sanitation with 1842 workers.

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
#We reduce the dataframe to the salary column only
streetsan = HYPO_df[HYPO_df['Department']=='STREETS & SAN']
streetsan_salary=streetsan['Hourly Rate'].dropna()
streetsan_salary
# Out:
# 15       40.78
# 16       38.52
# 26       38.52
# 49       29.96
# 65       37.45
#          ...
# 33623    38.01
# 33624    37.45
# 33667    37.45
# 33668    38.52
# 33676    25.95
# Name: Hourly Rate, Length: 1846, dtype: float64

# %%
# One-sided test:
# Null hypothesis or H0: hourly wage  >= 35
# Alternative hyp or H1: hourly wage < 35
stat, pval = ttest_1samp(streetsan_salary, 35) 
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# pvalue for the one-tailed test is  3.2902372218867895e-05

# %%
# p is low,we reject the H0
#We can say with a 95% confidence that the hourly wage is not above or equal to $35.

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# we can find a confidence interval for the population based on our sample
import scipy.stats
#We choose a confidence level of 95%
confidence_level = 0.95
degrees_freedom = len(clean_HR) - 1  
sample_mean = np.mean(clean_HR)

# %%
sample_standard_error = scipy.stats.sem(clean_HR)

# %%
#Confidence interval
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204317, 34.874504045196865) .

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
#Confidence Interval for police salaries
confidence_level = 0.95
degrees_freedom = len(police_salary) - 1  
sample_mean = np.mean(police_salary)

# %%
sample_standard_error = scipy.stats.sem(police_salary)

# %%
#Confidence interval
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (88534.1182885883, 89134.11955863392) .

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
